# %% [markdown]
# <a href="https://colab.research.google.com/github/SagiYosofov/Example/blob/master/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***This cell is for printing***

# %%
import time
print(time.ctime())
# Out:
# Wed Nov 13 18:37:58 2024

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Wed Nov 13 18:38:03 2024

# %% [markdown]
# # ***Hello World Example***

# %%
print("Hello", "world!")
# Out:
# Hello world!

# %%
# !pip install numpy

# %% [markdown]
# # ***Connecting to Google Drive***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# ColabIntroTutorial.ipynb  MyFirstColabNotebook.ipynb

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
print(y)
x = [x for x in range(len(y))]
print(x)

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()
# Out:
# [ 0.79517192 -0.31604232 -1.31229131  1.89737873  2.04147448 -1.06217351
#   1.12083708  2.23611031 -0.25849458  1.16978038  0.70088126 -0.0712183
#   2.32379467 -0.1473658  -0.38488152  1.89953146  0.4608157   1.43052623
#  -0.48166991  0.4686741   0.11281359 -0.30240719  0.37097524  1.05991005
#   0.27236185  0.06820572 -1.04313343  1.63114203  0.66200513  1.05564432
#  -0.52845475 -0.62959594 -0.61645207 -0.03854104 -0.45072665 -0.14431154
#  -1.9276273  -1.25715125  0.60532962  1.3466485   1.99319131  1.44027944
#  -1.19650962  2.24140608 -1.24488431 -0.26678447 -0.38155199  0.76344644
#  -1.59233198  0.11963534  1.02536052  0.41943048  1.38821624  1.49230735
#  -1.55162092 -0.05588153  1.47290537 -2.63691164  1.40106531 -1.25965638
#  -1.59966945  0.41985493 -0.30591316  0.70564651 -1.5760734   0.92225601
#   0.5859927  -0.79422412  1.31721056  0.65222639 -0.29096588  0.4232647
#  -0.23676967 -0.11960061  1.94115498  0.97823781  0.24680499 -1.48972057
# ...

# %%
# @title My Form
name = "" # @param {"type":"string","placeholder":"name:"}
lastName = "" # @param {"type":"string","placeholder":"lastName"}
age = 0 # @param {"type":"integer","placeholder":"age"}
startDate = "2024-11-13" # @param {"type":"date","placeholder":"startDate"}
sleepTime = 0 # @param {"type":"integer","placeholder":"sleepTime"}
color = "blue" # @param ["blue","yello","green","red"]

# %%
#@title Complete Form Example
# %%html
<style>
body{
background-color: #f2bcca;
}
</style>
color='green'#@param["red","green","blue"]print(color)
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
  <rect x="10" y="00"  width="300" height="100" rx="0" style="fill:orange;  stroke:black; fill-opacity:1.0" />
  <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white;   stroke:black; fill-opacity:1.0;" />
  <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green;   stroke:black; fill-opacity:1.0;" />
</svg>
# Out:
# <style>
# body{
# background-color: #f2bcca;
# }
# </style>
# color='green'#@param["red","green","blue"]print(color)
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#   <rect x="10" y="00"  width="300" height="100" rx="0" style="fill:orange;  stroke:black; fill-opacity:1.0" />
#   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white;   stroke:black; fill-opacity:1.0;" />
#   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green;   stroke:black; fill-opacity:1.0;" />
# </svg>
